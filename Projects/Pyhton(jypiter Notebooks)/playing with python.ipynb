# %%
import pandas as pd

# %%
database = pd.read_csv("annual-enterprise-survey-2020-financial-year-provisional-csv.csv")

# %%
database.head(5)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
database.tail(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37070  2013                     Level 3                 ZZ11
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 37070  Food product manufacturing  Dollars (millions)           H32
# 37071  Food product manufacturing  Dollars (millions)           H33
# 37072  Food product manufacturing             Dollars           H34
# ...

# %%
database.iloc[37077]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 database.iloc[37077]
#
# NameError: name 'database' is not defined

# %%
database.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 database.dtype
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
database.values
# Out:
# array([[2020, 'Level 1', '99999', ..., 'Financial performance',
#         '733,258',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2020, 'Level 1', '99999', ..., 'Financial performance',
#         '660,630',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2020, 'Level 1', '99999', ..., 'Financial performance', '54,342',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        ...,
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '12',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '5',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
# ...

# %%
type(database.values)
# Out:
# numpy.ndarray

# %%
database.index
# Out:
# RangeIndex(start=0, stop=37080, step=1)

# %%
database
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
(database, index=['200','30000','250','277'])
# Out:
#   Input In [16]
#     (database, index=['200','30000','250','277'])
#                ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
database.iloc[200]
# Out:
# Year                                                   2020
# Industry_aggregation_NZSIOC                         Level 3
# Industry_code_NZSIOC                                   AA13
# Industry_name_NZSIOC                   Dairy Cattle Farming
# Units                                    Dollars (millions)
# Variable_code                                           H30
# Variable_name                  Total equity and liabilities
# Variable_category                        Financial position
# Value                                                68,503
# Industry_code_ANZSIC06                  ANZSIC06 group A016
# Name: 200, dtype: object

# %%
database.iloc[[3000, 2222]]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 3000  2020                     Level 3                 JJ11
# 2222  2020                     Level 4                FF116
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 3000    Information Media Services  Dollars (millions)           H21
# 2222  Commission Based Wholesaling  Dollars (millions)           H05
#
#                           Variable_name      Variable_category Value  \
# 3000                     Opening stocks  Financial performance   162
# 2222  Interest, dividends and donations  Financial performance    16
#
#                                  Industry_code_ANZSIC06
# 3000  ANZSIC06 groups J541, J542, J551, J552, J561, ...
# 2222                                ANZSIC06 Group F380

# %%
database.iloc[[1, 5, 20, 30]]
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 1   2020                     Level 1                99999
# 5   2020                     Level 1                99999
# 20  2020                     Level 1                99999
# 30  2020                     Level 1                99999
#
#    Industry_name_NZSIOC               Units Variable_code  \
# 1        All industries  Dollars (millions)           H04
# 5        All industries  Dollars (millions)           H09
# 20       All industries  Dollars (millions)           H30
# 30       All industries          Percentage           H41
#
#                                       Variable_name      Variable_category  \
# 1   Sales, government funding, grants and subsidies  Financial performance
# 5                            Interest and donations  Financial performance
# 20                     Total equity and liabilities     Financial position
# 30                            Liabilities structure       Financial ratios
#
# ...

# %%
database.iloc[-1]
# Out:
# Year                                                                        2013
# Industry_aggregation_NZSIOC                                              Level 3
# Industry_code_NZSIOC                                                        ZZ11
# Industry_name_NZSIOC                                  Food product manufacturing
# Units                                                                 Percentage
# Variable_code                                                                H41
# Variable_name                                              Liabilities structure
# Variable_category                                               Financial ratios
# Value                                                                         46
# Industry_code_ANZSIC06         ANZSIC06 groups C111, C112, C113, C114, C115, ...
# Name: 37079, dtype: object

# %%
database['Industry_aggregation_NZSIOC']
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 37075    Level 3
# 37076    Level 3
# 37077    Level 3
# 37078    Level 3
# 37079    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 37080, dtype: object

# %%
database[['Industry_name_NZSIOC','Units']]
# Out:
#              Industry_name_NZSIOC               Units
# 0                  All industries  Dollars (millions)
# 1                  All industries  Dollars (millions)
# 2                  All industries  Dollars (millions)
# 3                  All industries  Dollars (millions)
# 4                  All industries  Dollars (millions)
# ...                           ...                 ...
# 37075  Food product manufacturing          Percentage
# 37076  Food product manufacturing          Percentage
# 37077  Food product manufacturing          Percentage
# 37078  Food product manufacturing          Percentage
# 37079  Food product manufacturing          Percentage
#
# [37080 rows x 2 columns]

# %%
database.iloc[37075]
# Out:
# Year                                                                        2013
# Industry_aggregation_NZSIOC                                              Level 3
# Industry_code_NZSIOC                                                        ZZ11
# Industry_name_NZSIOC                                  Food product manufacturing
# Units                                                                 Percentage
# Variable_code                                                                H37
# Variable_name                                                        Quick ratio
# Variable_category                                               Financial ratios
# Value                                                                         52
# Industry_code_ANZSIC06         ANZSIC06 groups C111, C112, C113, C114, C115, ...
# Name: 37075, dtype: object

# %%
l = database.iloc

# %%
l[240]
# Out:
# Year                                                                2020
# Industry_aggregation_NZSIOC                                      Level 4
# Industry_code_NZSIOC                                               AA141
# Industry_name_NZSIOC           Poultry, Deer and Other Livestock Farming
# Units                                                         Percentage
# Variable_code                                                        H41
# Variable_name                                      Liabilities structure
# Variable_category                                       Financial ratios
# Value                                                                 40
# Industry_code_ANZSIC06              ANZSIC06 groups A017, A018, and A019
# Name: 240, dtype: object

# %%
database['200': '400']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 database['200': '400']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3477, in DataFrame.__getitem__(self, key)
#    3474         return self._get_item_cache(key)
#    3476 # Do we have a slicer (on rows)?
# -> 3477 indexer = convert_to_index_sliceable(self, key)
#    3478 if indexer is not None:
#    3479     if isinstance(indexer, np.ndarray):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:2324, in convert_to_index_sliceable(obj, key)
#    2322 idx = obj.index
#    2323 if isinstance(key, slice):
# -> 2324     return idx._convert_slice_indexer(key, kind="getitem")
#    2326 elif isinstance(key, str):
#    2327
#    2328     # we are an actual column
#    2329     if key in obj.columns:
#
# ...

# %%
Industry_code_NZSIOC * 1000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 Industry_code_NZSIOC * 1000
#
# NameError: name 'Industry_code_NZSIOC' is not defined

# %%
database < 1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 database < 1000
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6934, in DataFrame._cmp_method(self, other, op)
# ...

# %%
database > 1000

# %%
database
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
Value < 44
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 Value < 44
#
# NameError: name 'Value' is not defined

# %%
database.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
database.info
# Out:
# <bound method DataFrame.info of        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
database.index
# Out:
# RangeIndex(start=0, stop=37080, step=1)

# %%
database.shape
# Out:
# (37080, 10)

# %%
database.describe
# Out:
# <bound method NDFrame.describe of        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
database.loc['200':'400']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 database.loc['200':'400']
#
# NameError: name 'database' is not defined

# %%
database.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 database.head
#
# NameError: name 'database' is not defined

# %%
database.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 database.head(10)
#
# NameError: name 'database' is not defined
